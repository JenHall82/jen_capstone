# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ply
import seaborn as sns

# %%
chester_county = pd.read_csv('../data/chester_county.csv')

# %%
chester_county.
# Out:
#                                                  Fact  \
# 0         Population estimates, July 1, 2023, (V2023)
# 1         Population Estimates, July 1, 2022, (V2022)
# 2   Population estimates base, April 1, 2020, (V2023)
# 3   Population estimates base, April 1, 2020, (V2022)
# 4   Population, percent change - April 1, 2020 (es...
# ..                                                ...
# 83                                                 FN
# 84                                                  X
# 85                                                  S
# 86                                                NaN
# 87                                                  Z
#
#                                             Fact Note  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 83             Footnote on this item in place of data
# 84                                     Not applicable
# 85    Suppressed; does not meet publication standards
# 86                                      Not available
# 87  Value greater than zero but less than half uni...
#
#    Chester County, Tennessee  Value Note for Chester County, Tennessee
# 0                        NaN                                       NaN
# 1                     17,609                                       NaN
# 2                        NaN                                       NaN
# 3                     17,348                                       NaN
# 4                        NaN                                       NaN
# ..                       ...                                       ...
# 83                       NaN                                       NaN
# 84                       NaN                                       NaN
# 85                       NaN                                       NaN
# 86                       NaN                                       NaN
# 87                       NaN                                       NaN
#
# [88 rows x 4 columns]
